# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
import warnings
warnings.filterwarnings('ignore')
import sys
sys.path.insert(0,'/home/_shared/_projects/nucl_gmx')
from nucl_sys import systems as sys
import pynucl

# %%
#logging.basicConfig(level=logging.DEBUG)

# %%
p=pynucl.nucltrj(**sys['1kx5_sym_opc'],time=(0,None,1),fullseqs='1KX5')

# %%
#p.view()

# %%
c=pynucl.a_contacts(p,'(H3 or H4 or H2A or H2B) and side1','nucleic')
# Out:
# 100%|██████████| 1014/1014 [01:07<00:00, 15.11it/s]

# %%
d=c.get_num_int_profile()

# %%
# %%time
pynucl.plot_bar(d,p,column='num_int',dpi=300,debug=False,feature_types=['helix','-->','frameblock'])
# Out:
# CPU times: user 18.6 s, sys: 745 ms, total: 19.4 s
# Wall time: 27.3 s
# [<ggplot: (8736500894156)>,
#  <ggplot: (8736501082842)>,
#  <ggplot: (8736499609576)>,
#  <ggplot: (8736500513014)>]
