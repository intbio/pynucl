# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
import warnings
warnings.filterwarnings('ignore')
import sys
sys.path.insert(0,'/home/_shared/_projects/nucl_gmx')
from nucl_sys import systems as sys
import pynucl
from plotnine import ylim

# %%
#logging.basicConfig(level=logging.DEBUG)

# %%
p=pynucl.nucltrj('/home/g_vykhodsev/projects/Nucl+Snf2/GMX_system/sys_ref.pdb',
'/home/g_vykhodsev/projects/Nucl+Snf2/big_data/sys_md.xtc')
# Out:
# 101 frames loaded for sys_ref

# %%
# Out:
# (0, None, 1)

# %%
slice(*p.time)
# Out:
# slice(0, None, 1)

# %%
c=pynucl.a_contacts(p,'nucleic','segid O')
d=c.get_num_int_profile()

# %%
c.get_stable_int_profile()
# Out:
#    segid  resid  num_int
# 0      I     21       12
# 1      I     22       22
# 2      I     23       74
# 3      I     24       44
# 4      I     25       22
# 5      I     26        4
# 6      J    -24       14
# 7      J    -23       59
# 8      J    -22       12
# 9      J    -21       36
# 10     J    -20       51
# 11     J    -19       21

# %%
pl=pynucl.plot_line(d,p,columns=['num_int'],dpi=300,debug=False)

# %%
pl
# Out:
# [<ggplot: (8760023753455)>, <ggplot: (-9223363276865752316)>]

# %%
# %%time
pynucl.plot_bar(d,p,column='num_int',dpi=300,debug=False,feature_types=['helix','-->','frameblock'])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <timed eval> in <module>
#
# /home/_shared/package_dev/pynucl/pynucl/plot1d.py in for_every_segid(data, *args, **kwargs)
#      46             for s in segids:
#      47                 retobj.append(func(data[data.segid.eq(s)],*args,**kwargs))
# ---> 48         return retobj
#      49     return for_every_segid
#      50
#
# UnboundLocalError: local variable 'retobj' referenced before assignment

# %%
p.vmd_lv()
# Out:
# ...
# mkdir -p sys_ref
# cd sys_ref
# rsync -avz node_07:/home/_shared/package_dev/pynucl/pynucl/data//VMD_scripts/* .
# rsync -avz node_07:/home/_shared/package_dev/pynucl/examples/tmp/sys_ref* .
# vmd -e view_nucl.tcl -args sys_ref.pdb sys_ref.xtc sys_ref 0 0 1 1 1 1 1 0 0 sys_ref.pdb

# %%
mkdir -p sys_ref
cd sys_ref
rsync -avz newton:/home/_shared/package_dev/pynucl/pynucl/data//VMD_scripts/* .
