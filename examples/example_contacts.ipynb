# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import warnings
warnings.filterwarnings('ignore')
import sys
sys.path.insert(0,'/home/_shared/_projects/nucl_gmx')
from nucl_sys import systems as sys
import pynucl
from plotnine import ylim

# %%
#logging.basicConfig(level=logging.DEBUG)

# %%
p=pynucl.nucltrj(**sys['1kx5_sym_opc'],time=(0,None,1),fullseqs='1KX5')
# Out:
# /opt/miniconda3/envs/moldyn/lib/python3.7/site-packages/MDAnalysis/analysis/base.py:116: DeprecationWarning: Setting the following kwargs should be done in the run() method: start, step
#   DeprecationWarning)

# %%
slice(*p.time)
# Out:
# slice(0, None, 1)

# %%
c=pynucl.a_contacts(p,'(H3 or H4) and side1','nucleic',time=(0,10,1))
d=c.get_num_int_profile()
pl=pynucl.plot_line(d,p,columns=['num_int'],dpi=300,debug=False,feature_types=['helix','-->','frameblock'])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
(pl[0]+ylim(-200,200))
# Out:
# <ggplot: (-9223363265072306025)>

# %%
# Out:
# CPU times: user 8.87 s, sys: 381 ms, total: 9.25 s
# Wall time: 13.1 s
# [<ggplot: (8754478607785)>, <ggplot: (-9223363282376190418)>]

# %%
# %%time
pynucl.plot_bar(d,p,column='num_int',dpi=300,debug=False,feature_types=['helix','-->','frameblock'])
# Out:
# CPU times: user 9.25 s, sys: 333 ms, total: 9.59 s
# Wall time: 13.5 s
# [<ggplot: (-9223363282445667212)>, <ggplot: (-9223363282260578942)>]
